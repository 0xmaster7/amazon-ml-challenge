# %% [markdown]
# # Colab Runner - Amazon ML Challenge
# This notebook downloads the dataset to Colab's fast temporary storage and runs `train.py`, saving checkpoints directly to your Google Drive.

# %%
# 1. Mount Google Drive (This is where checkpoints will be saved/loaded)
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Setup Kaggle CLI to download the dataset
# !pip install kaggle
# !mkdir -p ~/.kaggle

# IMPORTANT: Upload your kaggle.json to your Google Drive root first, or copy it here:
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download and unzip dataset to Colab's temporary storage (very fast)
# !kaggle competitions download -c amazon-ml-challenge # REPLACE WITH ACTUAL COMPETITION NAME
# !unzip -q amazon-ml-challenge.zip -d /content/dataset

# %%
# 3. Run the Training Script
# It reads from /content/dataset and saves/resumes from your Drive
# !python train.py --data_dir /content/dataset --checkpoint_dir "/content/drive/MyDrive/AmazonML_Checkpoints" --epochs 10
